# %% [markdown]
# # Import the necessary modules

# %%
##########################
#Importing necessary Modules
##########################
import urllib.request as urllib2 # to download websites
import re # for regular expression
from bs4 import BeautifulSoup # to parse the websites
import re
import json
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np
import time
import parser
import re
import nltk.corpus
from nltk.tokenize import sent_tokenize
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
import matplotlib.pyplot as plt
import sys
import operator
import random
import argparse
import sys
import operator
import argparse
import stdin
from nltk.tokenize import word_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.corpus import movie_reviews
from nltk import FreqDist
from nltk.probability import FreqDist
from nltk.book import *
from textblob import TextBlob
from textblob import TextBlob, Word

# %% [markdown]
# # Load the webpage from the URL

# %%
url = "http://edition.cnn.com/2018/01/21/politics/macron-trump-relationship-intl/index.html"
html = urllib2.urlopen(url).read()
soup = BeautifulSoup(html, "html.parser")
for line in soup(["script", "style"]):     
    line.extract()
    
    
text = soup.get_text()
text
# Out:
# 'Macron: \'I have a very direct relationship with Trump\'  - CNNPoliticsBreaking News45CongressSecurityThe NineTrumpmericaStateSearch »French President Macron has \'a very direct relationship with Trump\' By Sheena McKenzie, Carol Jordan and Amanda Coakley, CNNUpdated 0749 GMT (1549 HKT) January 22, 2018 Chat with us in Facebook Messenger. Find out what\'s happening in the world as it unfolds.JUST WATCHEDWhat to know about Emmanuel MacronReplayMore Videos ...MUST WATCHWhat to know about Emmanuel Macron 01:32 (CNN)Their first meeting in Brussels was symbolized by a prolonged, white-knuckle handshake -- and months later it appears French President Emmanuel Macron and US President Donald Trump continue to have forceful exchanges.Macron shed light Sunday on his "very direct relationship" with Trump, telling the BBC\'s "The Andrew Marr Show" that the two leaders talk "very regularly.""I\'m always extremely direct and frank. He is. Sometimes I manage to convince him, and sometimes I fail," Macron said on the British talk show.Macron added that Trump was "not a classical politician" and was "elected by his humoring people."Paris agreement: \'no renegotiation\'Read MoreMacron, who was elected in May last year, said the two leaders had "built a very strong relationship." However they also disagreed on several topics, including the Paris agreement on climate change, from which Trump plans to withdraw unless the terms are renegotiated.Macron said the US could only choose between signing or not signing the treaty, adding "we will not renegotiate for one people."JUST WATCHEDPM warns Trump: Don\'t miss a good opportunityReplayMore Videos ...MUST WATCHPM warns Trump: Don\'t miss a good opportunity 02:22"I do believe that\'s a big mistake, I told him but there is no new negotiation. You join or you don\'t join. China decided to, to remain in the loop," Macron said.The Paris agreement pushes signatories to reduce their carbon output and hold global warming below two degrees Celsius by the end of the century.While former President Barack Obama described it as "best chance we have to save the one planet that we\'ve got," Trump has been far from as complimentary.As things stand, the US will be the only country in the world not signed on to the accord when it completes the lengthy withdrawal process in 2020.\'It\'s not a word you can use\' Macron also criticized Trump\'s alleged use of the word "shitholes" to describe certain countries while discussing immigration with lawmakers earlier this month. A year of Trump: (Almost) everything that happened"It\'s not a word you can use," said Macron about Trump\'s reported comment, adding "we have to respect all the countries.""I think a lot of our issues in both the Middle East and in Africa is due to a lot of frustrations due to a lot of past humiliations," Macron said.When asked about his opinion on Trump\'s tweets, Macron replied that people shouldn\'t "overplay the situation," saying the tweets are a "mix between personal and political reaction."Macron: Trump\'s interpreter in Europe?Macron  is one in a small club of leaders with less experience in office than Trump. The 40-year-old French President appears to have used that to his advantage, forging strong ties with the White House based on a mutual desire to change the status quo.Read more: Trump\'s first year -- diplomacy finds friends and foes Trump has replaced old international allies with new onesSince their first eye-catching handshake in Brussels, there have been highs (an intimate dinner with wives on the second landing of the Eiffel Tower) and lows (Macron has openly aired his disagreements with Trump on Iran, climate change and the Middle East.)Through it all, Macron\'s aides say he views himself as Trump\'s interpreter in Europe, sifting through the brash pronouncements to find places of common interest. And as leaders in Berlin and London find themselves distracted by internal politics, including coalition negotiations and Brexit, Paris- ...

# %% [markdown]
# # Get text data from the webpage

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.1-py2.py3-none-any.whl (631kB)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.1

# %% [markdown]
# # Process the text

# %%
text1 = 'Macron: \'I have a very direct relationship with Trump\'  - CNNPoliticsBreaking News45CongressSecurityThe NineTrumpmericaStateSearch »French President Macron has \'a very direct relationship with Trump\' By Sheena McKenzie, Carol Jordan and Amanda Coakley, CNNUpdated 0749 GMT (1549 HKT) January 22, 2018 Chat with us in Facebook Messenger. Find out what\'s happening in the world as it unfolds.JUST WATCHEDWhat to know about Emmanuel MacronReplayMore Videos ...MUST WATCHWhat to know about Emmanuel Macron 01:32 (CNN)Their first meeting in Brussels was symbolized by a prolonged, white-knuckle handshake -- and months later it appears French President Emmanuel Macron and US President Donald Trump continue to have forceful exchanges.Macron shed light Sunday on his "very direct relationship" with Trump, telling the BBC\'s "The Andrew Marr Show" that the two leaders talk "very regularly.""I\'m always extremely direct and frank. He is. Sometimes I manage to convince him, and sometimes I fail," Macron said on the British talk show.Macron added that Trump was "not a classical politician" and was "elected by his humoring people."Paris agreement: \'no renegotiation\'Read MoreMacron, who was elected in May last year, said the two leaders had "built a very strong relationship." However they also disagreed on several topics, including the Paris agreement on climate change, from which Trump plans to withdraw unless the terms are renegotiated.Macron said the US could only choose between signing or not signing the treaty, adding "we will not renegotiate for one people."JUST WATCHEDPM warns Trump: Don\'t miss a good opportunityReplayMore Videos ...MUST WATCHPM warns Trump: Don\'t miss a good opportunity 02:22"I do believe that\'s a big mistake, I told him but there is no new negotiation. You join or you don\'t join. China decided to, to remain in the loop," Macron said.The Paris agreement pushes signatories to reduce their carbon output and hold global warming below two degrees Celsius by the end of the century.While former President Barack Obama described it as "best chance we have to save the one planet that we\'ve got," Trump has been far from as complimentary.As things stand, the US will be the only country in the world not signed on to the accord when it completes the lengthy withdrawal process in 2020.\'It\'s not a word you can use\' Macron also criticized Trump\'s alleged use of the word "shitholes" to describe certain countries while discussing immigration with lawmakers earlier this month. A year of Trump: (Almost) everything that happened"It\'s not a word you can use," said Macron about Trump\'s reported comment, adding "we have to respect all the countries.""I think a lot of our issues in both the Middle East and in Africa is due to a lot of frustrations due to a lot of past humiliations," Macron said.When asked about his opinion on Trump\'s tweets, Macron replied that people shouldn\'t "overplay the situation," saying the tweets are a "mix between personal and political reaction."Macron: Trump\'s interpreter in Europe?Macron  is one in a small club of leaders with less experience in office than Trump. The 40-year-old French President appears to have used that to his advantage, forging strong ties with the White House based on a mutual desire to change the status quo.Read more: Trump\'s first year -- diplomacy finds friends and foes Trump has replaced old international allies with new onesSince their first eye-catching handshake in Brussels, there have been highs (an intimate dinner with wives on the second landing of the Eiffel Tower) and lows (Macron has openly aired his disagreements with Trump on Iran, climate change and the Middle East.)Through it all, Macron\'s aides say he views himself as Trump\'s interpreter in Europe, sifting through the brash pronouncements to find places of common interest. And as leaders in Berlin and London find themselves distracted by internal politics, including coalition negotiations and Brexit, Paris-Washington ties are enjoying renewed strength. CNN\'s Kevin Liptak and Dan Merica contributed to this report 45CongressSecurityThe NineTrumpmericaState© 2018 Cable News Network. Turner Broadcasting System, Inc. All Rights Reserved. CNN Sans ™ & © 2016 Cable News Network.Terms of service | Privacy guidelines | AdChoices'
tokens = word_tokenize(text1)
tokens
# Out:
# ['Macron',
#  ':',
#  "'I",
#  'have',
#  'a',
#  'very',
#  'direct',
#  'relationship',
#  'with',
#  'Trump',
#  "'",
#  '-',
#  'CNNPoliticsBreaking',
#  'News45CongressSecurityThe',
#  'NineTrumpmericaStateSearch',
#  '»',
#  'French',
#  'President',
#  'Macron',
#  'has',
#  "'a",
#  'very',
#  'direct',
#  'relationship',
#  'with',
#  'Trump',
#  "'",
#  'By',
#  'Sheena',
#  'McKenzie',
#  ',',
#  'Carol',
#  'Jordan',
#  'and',
#  'Amanda',
#  'Coakley',
#  ',',
#  'CNNUpdated',
#  '0749',
#  'GMT',
#  '(',
#  '1549',
#  'HKT',
#  ')',
#  'January',
#  '22',
#  ',',
#  '2018',
#  'Chat',
#  'with',
#  'us',
#  'in',
#  'Facebook',
#  'Messenger',
#  '.',
#  'Find',
#  'out',
#  'what',
#  "'s",
#  'happening',
#  'in',
#  'the',
#  'world',
#  'as',
#  'it',
#  'unfolds.JUST',
#  'WATCHEDWhat',
#  'to',
#  'know',
#  'about',
#  'Emmanuel',
#  'MacronReplayMore',
#  'Videos',
#  '...',
#  'MUST',
#  'WATCHWhat',
#  'to',
#  'know',
#  'about',
#  'Emmanuel',
#  'Macron',
#  '01:32',
#  '(',
#  'CNN',
#  ')',
#  'Their',
#  'first',
#  'meeting',
#  'in',
#  'Brussels',
#  'was',
#  'symbolized',
#  'by',
#  'a',
#  'prolonged',
#  ',',
#  'white-knuckle',
#  'handshake',
#  '--',
#  'and',
#  'months',
#  'later',
#  'it',
#  'appears',
#  'French',
#  'President',
#  'Emmanuel',
#  'Macron',
#  'and',
#  'US',
#  'President',
#  'Donald',
#  'Trump',
#  'continue',
#  'to',
#  'have',
#  'forceful',
#  'exchanges.Macron',
#  'shed',
#  'light',
#  'Sunday',
#  'on',
#  'his',
#  '``',
#  'very',
#  'direct',
#  'relationship',
#  "''",
#  'with',
#  'Trump',
#  ',',
#  'telling',
#  'the',
#  'BBC',
#  "'s",
#  '``',
#  'The',
#  'Andrew',
#  'Marr',
#  'Show',
#  "''",
#  'that',
#  'the',
#  'two',
#  'leaders',
#  'talk',
#  '``',
#  'very',
#  'regularly',
#  '.',
#  '``',
#  '``',
#  'I',
#  "'m",
#  'always',
#  'extremely',
#  'direct',
#  'and',
#  'frank',
#  '.',
#  'He',
#  'is',
#  '.',
#  'Sometimes',
#  'I',
#  'manage',
#  'to',
#  'convince',
#  'him',
#  ',',
#  'and',
#  'sometimes',
#  'I',
#  'fail',
#  ',',
#  "''",
#  'Macron',
#  'said',
#  'on',
#  'the',
#  'British',
#  'talk',
#  'show.Macron',
#  'added',
#  'that',
#  'Trump',
#  'was',
#  '``',
#  'not',
#  'a',
#  'classical',
#  'politician',
#  "''",
#  'and',
#  'was',
#  '``',
#  'elected',
#  'by',
#  'his',
#  'humoring',
#  'people',
#  '.',
#  '``',
#  'Paris',
#  'agreement',
#  ':',
#  "'no",
#  "renegotiation'Read",
#  'MoreMacron',
#  ',',
#  'who',
#  'was',
#  'elected',
#  'in',
#  'May',
#  'last',
#  'year',
#  ',',
#  'said',
#  'the',
#  'two',
#  'leaders',
#  'had',
#  '``',
#  'built',
#  'a',
#  'very',
#  'strong',
#  'relationship',
#  '.',
#  "''",
#  'However',
#  'they',
#  'also',
#  'disagreed',
#  'on',
#  'several',
#  'topics',
#  ',',
#  'including',
#  'the',
#  'Paris',
#  'agreement',
#  'on',
#  'climate',
#  'change',
#  ',',
#  'from',
#  'which',
#  'Trump',
#  'plans',
#  'to',
#  'withdraw',
#  'unless',
#  'the',
#  'terms',
#  'are',
#  'renegotiated.Macron',
#  'said',
#  'the',
#  'US',
#  'could',
#  'only',
#  'choose',
#  'between',
#  'signing',
#  'or',
#  'not',
#  'signing',
#  'the',
#  'treaty',
#  ',',
#  'adding',
#  '``',
#  'we',
#  'will',
#  'not',
#  'renegotiate',
#  'for',
#  'one',
#  'people',
#  '.',
#  '``',
#  'JUST',
#  'WATCHEDPM',
#  'warns',
#  'Trump',
#  ':',
#  'Do',
#  "n't",
#  'miss',
#  'a',
#  'good',
#  'opportunityReplayMore',
#  'Videos',
#  '...',
#  'MUST',
#  'WATCHPM',
#  'warns',
#  'Trump',
#  ':',
#  'Do',
#  "n't",
#  'miss',
#  'a',
#  'good',
#  'opportunity',
#  '02:22',
#  "''",
#  'I',
#  'do',
#  'believe',
#  'that',
#  "'s",
#  'a',
#  'big',
#  'mistake',
#  ',',
#  'I',
#  'told',
#  'him',
#  'but',
#  'there',
#  'is',
#  'no',
#  'new',
#  'negotiation',
#  '.',
#  'You',
#  'join',
#  'or',
#  'you',
#  'do',
#  "n't",
#  'join',
#  '.',
#  'China',
#  'decided',
#  'to',
#  ',',
#  'to',
#  'remain',
#  'in',
#  'the',
#  'loop',
#  ',',
#  "''",
#  'Macron',
#  'said.The',
#  'Paris',
#  'agreement',
#  'pushes',
#  'signatories',
#  'to',
#  'reduce',
#  'their',
#  'carbon',
#  'output',
#  'and',
#  'hold',
#  'global',
#  'warming',
#  'below',
#  'two',
#  'degrees',
#  'Celsius',
#  'by',
#  'the',
#  'end',
#  'of',
#  'the',
#  'century.While',
#  'former',
#  'President',
#  'Barack',
#  'Obama',
#  'described',
#  'it',
#  'as',
#  '``',
#  'best',
#  'chance',
#  'we',
#  'have',
#  'to',
#  'save',
#  'the',
#  'one',
#  'planet',
#  'that',
#  'we',
#  "'ve",
#  'got',
#  ',',
#  "''",
#  'Trump',
#  'has',
#  'been',
#  'far',
#  'from',
#  'as',
#  'complimentary.As',
#  'things',
#  'stand',
#  ',',
#  'the',
#  'US',
#  'will',
#  'be',
#  'the',
#  'only',
#  'country',
#  'in',
#  'the',
#  'world',
#  'not',
#  'signed',
#  'on',
#  'to',
#  'the',
#  'accord',
#  'when',
#  'it',
#  'completes',
#  'the',
#  'lengthy',
#  'withdrawal',
#  'process',
#  'in',
#  '2020',
#  '.',
#  "'It",
#  "'s",
#  'not',
#  'a',
#  'word',
#  'you',
#  'can',
#  'use',
#  "'",
#  'Macron',
#  'also',
#  'criticized',
#  'Trump',
#  "'s",
#  'alleged',
#  'use',
#  'of',
#  'the',
#  'word',
#  '``',
#  'shitholes',
#  "''",
#  'to',
#  'describe',
#  'certain',
#  'countries',
#  'while',
#  'discussing',
#  'immigration',
#  'with',
#  'lawmakers',
#  'earlier',
#  'this',
#  'month',
#  '.',
#  'A',
#  'year',
#  'of',
#  'Trump',
#  ':',
#  '(',
#  'Almost',
#  ')',
#  'everything',
#  'that',
#  'happened',
#  "''",
#  'It',
#  "'s",
#  'not',
#  'a',
#  'word',
#  'you',
#  'can',
#  'use',
#  ',',
#  "''",
#  'said',
#  'Macron',
#  'about',
#  'Trump',
#  "'s",
#  'reported',
#  'comment',
#  ',',
#  'adding',
#  '``',
#  'we',
#  'have',
#  'to',
#  'respect',
#  'all',
#  'the',
#  'countries',
#  '.',
#  '``',
#  '``',
#  'I',
#  'think',
#  'a',
#  'lot',
#  'of',
#  'our',
#  'issues',
#  'in',
#  'both',
#  'the',
#  'Middle',
#  'East',
#  'and',
#  'in',
#  'Africa',
#  'is',
#  'due',
#  'to',
#  'a',
#  'lot',
#  'of',
#  'frustrations',
#  'due',
#  'to',
#  'a',
#  'lot',
#  'of',
#  'past',
#  'humiliations',
#  ',',
#  "''",
#  'Macron',
#  'said.When',
#  'asked',
#  'about',
#  'his',
#  'opinion',
#  'on',
#  'Trump',
#  "'s",
#  'tweets',
#  ',',
#  'Macron',
#  'replied',
#  'that',
#  'people',
#  'should',
#  "n't",
#  '``',
#  'overplay',
#  'the',
#  'situation',
#  ',',
#  "''",
#  'saying',
#  'the',
#  'tweets',
#  'are',
#  'a',
#  '``',
#  'mix',
#  'between',
#  'personal',
#  'and',
#  'political',
#  'reaction',
#  '.',
#  '``',
#  'Macron',
#  ':',
#  'Trump',
#  "'s",
#  'interpreter',
#  'in',
#  'Europe',
#  '?',
#  'Macron',
#  'is',
#  'one',
#  'in',
#  'a',
#  'small',
#  'club',
#  'of',
#  'leaders',
#  'with',
#  'less',
#  'experience',
#  'in',
#  'office',
#  'than',
#  'Trump',
#  '.',
#  'The',
#  '40-year-old',
#  'French',
#  'President',
#  'appears',
#  'to',
#  'have',
#  'used',
#  'that',
#  'to',
#  'his',
#  'advantage',
#  ',',
#  'forging',
#  'strong',
#  'ties',
#  'with',
#  'the',
#  'White',
#  'House',
#  'based',
#  'on',
#  'a',
#  'mutual',
#  'desire',
#  'to',
#  'change',
#  'the',
#  'status',
#  'quo.Read',
#  'more',
#  ':',
#  'Trump',
#  "'s",
#  'first',
#  'year',
#  '--',
#  'diplomacy',
#  'finds',
#  'friends',
#  'and',
#  'foes',
#  'Trump',
#  'has',
#  'replaced',
#  'old',
#  'international',
#  'allies',
#  'with',
#  'new',
#  'onesSince',
#  'their',
#  'first',
#  'eye-catching',
#  'handshake',
#  'in',
#  'Brussels',
#  ',',
#  'there',
#  'have',
#  'been',
#  'highs',
#  '(',
#  'an',
#  'intimate',
#  'dinner',
#  'with',
#  'wives',
#  'on',
#  'the',
#  'second',
#  'landing',
#  'of',
#  'the',
#  'Eiffel',
#  'Tower',
#  ')',
#  'and',
#  'lows',
#  '(',
#  'Macron',
#  'has',
#  'openly',
#  'aired',
#  'his',
#  'disagreements',
#  'with',
#  'Trump',
#  'on',
#  'Iran',
#  ',',
#  'climate',
#  'change',
#  'and',
#  'the',
#  'Middle',
#  'East',
#  '.',
#  ')',
#  'Through',
#  'it',
#  'all',
#  ',',
#  'Macron',
#  "'s",
#  'aides',
#  'say',
#  'he',
#  'views',
#  'himself',
#  'as',
#  'Trump',
#  "'s",
#  'interpreter',
#  'in',
#  'Europe',
#  ',',
#  'sifting',
#  'through',
#  'the',
#  'brash',
#  'pronouncements',
#  'to',
#  'find',
#  'places',
#  'of',
#  'common',
#  'interest',
#  '.',
#  'And',
#  'as',
#  'leaders',
#  'in',
#  'Berlin',
#  'and',
#  'London',
#  'find',
#  'themselves',
#  'distracted',
#  'by',
#  'internal',
#  'politics',
#  ',',
#  'including',
#  'coalition',
#  'negotiations',
#  'and',
#  'Brexit',
#  ',',
#  'Paris-Washington',
#  'ties',
#  'are',
#  'enjoying',
#  'renewed',
#  'strength',
#  '.',
#  'CNN',
#  "'s",
#  'Kevin',
#  'Liptak',
#  'and',
#  'Dan',
#  'Merica',
#  'contributed',
#  'to',
#  'this',
#  'report',
#  '45CongressSecurityThe',
#  'NineTrumpmericaState©',
#  '2018',
#  'Cable',
#  'News',
#  'Network',
#  '.',
#  'Turner',
#  'Broadcasting',
#  'System',
#  ',',
#  'Inc.',
#  'All',
#  'Rights',
#  'Reserved',
#  '.',
#  'CNN',
#  'Sans',
#  '™',
#  '&',
#  '©',
#  '2016',
#  'Cable',
#  'News',
#  'Network.Terms',
#  'of',
#  'service',
#  '|',
#  'Privacy',
#  'guidelines',
#  '|',
#  'AdChoices']

# %% [markdown]
# # Part of speach tagging and frequency Calculation

# %%
document = word_tokenize(text)
nltk.pos_tag(document)
# Out:
# [('Macron', 'NN'),
#  (':', ':'),
#  ("'I", 'NNS'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('direct', 'JJ'),
#  ('relationship', 'NN'),
#  ('with', 'IN'),
#  ('Trump', 'NNP'),
#  ("'", 'POS'),
#  ('-', ':'),
#  ('CNNPoliticsBreaking', 'VBG'),
#  ('News45CongressSecurityThe', 'NNP'),
#  ('NineTrumpmericaStateSearch', 'NNP'),
#  ('»', 'NNP'),
#  ('French', 'NNP'),
#  ('President', 'NNP'),
#  ('Macron', 'NNP'),
#  ('has', 'VBZ'),
#  ("'a", 'VBN'),
#  ('very', 'RB'),
#  ('direct', 'JJ'),
#  ('relationship', 'NN'),
#  ('with', 'IN'),
#  ('Trump', 'NNP'),
#  ("'", 'POS'),
#  ('By', 'IN'),
#  ('Sheena', 'NNP'),
#  ('McKenzie', 'NNP'),
#  (',', ','),
#  ('Carol', 'NNP'),
#  ('Jordan', 'NNP'),
#  ('and', 'CC'),
#  ('Amanda', 'NNP'),
#  ('Coakley', 'NNP'),
#  (',', ','),
#  ('CNNUpdated', 'NNP'),
#  ('0749', 'CD'),
#  ('GMT', 'NNP'),
#  ('(', '('),
#  ('1549', 'CD'),
#  ('HKT', 'NNP'),
#  (')', ')'),
#  ('January', 'NNP'),
#  ('22', 'CD'),
#  (',', ','),
#  ('2018', 'CD'),
#  ('Chat', 'NNP'),
#  ('with', 'IN'),
#  ('us', 'PRP'),
#  ('in', 'IN'),
#  ('Facebook', 'NNP'),
#  ('Messenger', 'NNP'),
#  ('.', '.'),
#  ('Find', 'VB'),
#  ('out', 'RP'),
#  ('what', 'WP'),
#  ("'s", 'VBZ'),
#  ('happening', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('unfolds.JUST', 'VBZ'),
#  ('WATCHEDWhat', 'WP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('about', 'IN'),
#  ('Emmanuel', 'NNP'),
#  ('MacronReplayMore', 'NNP'),
#  ('Videos', 'NNP'),
#  ('...', ':'),
#  ('MUST', 'NNP'),
#  ('WATCHWhat', 'WP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('about', 'IN'),
#  ('Emmanuel', 'NNP'),
#  ('Macron', 'NNP'),
#  ('01:32', 'CD'),
#  ('(', '('),
#  ('CNN', 'NNP'),
#  (')', ')'),
#  ('Their', 'PRP$'),
#  ('first', 'JJ'),
#  ('meeting', 'NN'),
#  ('in', 'IN'),
#  ('Brussels', 'NNP'),
#  ('was', 'VBD'),
#  ('symbolized', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('prolonged', 'JJ'),
#  (',', ','),
#  ('white-knuckle', 'JJ'),
#  ('handshake', 'NN'),
#  ('--', ':'),
#  ('and', 'CC'),
#  ('months', 'NNS'),
#  ('later', 'RB'),
#  ('it', 'PRP'),
#  ('appears', 'VBZ'),
#  ('French', 'JJ'),
#  ('President', 'NNP'),
#  ('Emmanuel', 'NNP'),
#  ('Macron', 'NNP'),
#  ('and', 'CC'),
#  ('US', 'NNP'),
#  ('President', 'NNP'),
#  ('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ('continue', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('forceful', 'JJ'),
#  ('exchanges.Macron', 'NN'),
#  ('shed', 'VBD'),
#  ('light', 'JJ'),
#  ('Sunday', 'NNP'),
#  ('on', 'IN'),
#  ('his', 'PRP$'),
#  ('``', '``'),
#  ('very', 'RB'),
#  ('direct', 'JJ'),
#  ('relationship', 'NN'),
#  ("''", "''"),
#  ('with', 'IN'),
#  ('Trump', 'NNP'),
#  (',', ','),
#  ('telling', 'VBG'),
#  ('the', 'DT'),
#  ('BBC', 'NNP'),
#  ("'s", 'POS'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('Andrew', 'NNP'),
#  ('Marr', 'NNP'),
#  ('Show', 'NNP'),
#  ("''", "''"),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('leaders', 'NNS'),
#  ('talk', 'VBP'),
#  ('``', '``'),
#  ('very', 'RB'),
#  ('regularly', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('always', 'RB'),
#  ('extremely', 'RB'),
#  ('direct', 'JJ'),
#  ('and', 'CC'),
#  ('frank', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('.', '.'),
#  ('Sometimes', 'RB'),
#  ('I', 'PRP'),
#  ('manage', 'VBP'),
#  ('to', 'TO'),
#  ('convince', 'VB'),
#  ('him', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('sometimes', 'RB'),
#  ('I', 'PRP'),
#  ('fail', 'VBP'),
#  (',', ','),
#  ("''", "''"),
#  ('Macron', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('British', 'JJ'),
#  ('talk', 'NN'),
#  ('show.Macron', 'NN'),
#  ('added', 'VBD'),
#  ('that', 'IN'),
#  ('Trump', 'NNP'),
#  ('was', 'VBD'),
#  ('``', '``'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('classical', 'JJ'),
#  ('politician', 'NN'),
#  ("''", "''"),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('``', '``'),
#  ('elected', 'VBN'),
#  ('by', 'IN'),
#  ('his', 'PRP$'),
#  ('humoring', 'VBG'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Paris', 'NNP'),
#  ('agreement', 'NN'),
#  (':', ':'),
#  ("'no", 'POS'),
#  ("renegotiation'Read", 'NN'),
#  ('MoreMacron', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('elected', 'VBN'),
#  ('in', 'IN'),
#  ('May', 'NNP'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('leaders', 'NNS'),
#  ('had', 'VBD'),
#  ('``', '``'),
#  ('built', 'VBN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('strong', 'JJ'),
#  ('relationship', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('However', 'RB'),
#  ('they', 'PRP'),
#  ('also', 'RB'),
#  ('disagreed', 'VBP'),
#  ('on', 'IN'),
#  ('several', 'JJ'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('Paris', 'NNP'),
#  ('agreement', 'NN'),
#  ('on', 'IN'),
#  ('climate', 'NN'),
#  ('change', 'NN'),
#  (',', ','),
#  ('from', 'IN'),
#  ('which', 'WDT'),
#  ('Trump', 'NNP'),
#  ('plans', 'VBZ'),
#  ('to', 'TO'),
#  ('withdraw', 'VB'),
#  ('unless', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('are', 'VBP'),
#  ('renegotiated.Macron', 'VBN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('could', 'MD'),
#  ('only', 'RB'),
#  ('choose', 'VB'),
#  ('between', 'IN'),
#  ('signing', 'VBG'),
#  ('or', 'CC'),
#  ('not', 'RB'),
#  ('signing', 'VBG'),
#  ('the', 'DT'),
#  ('treaty', 'NN'),
#  (',', ','),
#  ('adding', 'VBG'),
#  ('``', '``'),
#  ('we', 'PRP'),
#  ('will', 'MD'),
#  ('not', 'RB'),
#  ('renegotiate', 'VB'),
#  ('for', 'IN'),
#  ('one', 'CD'),
#  ('people', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('JUST', 'NNP'),
#  ('WATCHEDPM', 'NNP'),
#  ('warns', 'VBZ'),
#  ('Trump', 'NNP'),
#  (':', ':'),
#  ('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('miss', 'VB'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('opportunityReplayMore', 'NN'),
#  ('Videos', 'NNP'),
#  ('...', ':'),
#  ('MUST', 'NNP'),
#  ('WATCHPM', 'NNP'),
#  ('warns', 'VBZ'),
#  ('Trump', 'NNP'),
#  (':', ':'),
#  ('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('miss', 'VB'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('opportunity', 'NN'),
#  ('02:22', 'CD'),
#  ("''", "''"),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('believe', 'VB'),
#  ('that', 'DT'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('big', 'JJ'),
#  ('mistake', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('told', 'VBD'),
#  ('him', 'PRP'),
#  ('but', 'CC'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('new', 'JJ'),
#  ('negotiation', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('join', 'VBP'),
#  ('or', 'CC'),
#  ('you', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('join', 'VB'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('decided', 'VBD'),
#  ('to', 'TO'),
#  (',', ','),
#  ('to', 'TO'),
#  ('remain', 'VB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('loop', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('Macron', 'NNP'),
#  ('said.The', 'VBD'),
#  ('Paris', 'NNP'),
#  ('agreement', 'NN'),
#  ('pushes', 'NNS'),
#  ('signatories', 'NNS'),
#  ('to', 'TO'),
#  ('reduce', 'VB'),
#  ('their', 'PRP$'),
#  ('carbon', 'NN'),
#  ('output', 'NN'),
#  ('and', 'CC'),
#  ('hold', 'VB'),
#  ('global', 'JJ'),
#  ('warming', 'VBG'),
#  ('below', 'IN'),
#  ('two', 'CD'),
#  ('degrees', 'NNS'),
#  ('Celsius', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('century.While', 'JJ'),
#  ('former', 'JJ'),
#  ('President', 'NNP'),
#  ('Barack', 'NNP'),
#  ('Obama', 'NNP'),
#  ('described', 'VBD'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('best', 'JJS'),
#  ('chance', 'NN'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('the', 'DT'),
#  ('one', 'CD'),
#  ('planet', 'NN'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ("'ve", 'VBP'),
#  ('got', 'VBN'),
#  (',', ','),
#  ("''", "''"),
#  ('Trump', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('far', 'RB'),
#  ('from', 'IN'),
#  ('as', 'IN'),
#  ('complimentary.As', 'JJ'),
#  ('things', 'NNS'),
#  ('stand', 'VBP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('only', 'JJ'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('not', 'RB'),
#  ('signed', 'VBN'),
#  ('on', 'IN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('accord', 'NN'),
#  ('when', 'WRB'),
#  ('it', 'PRP'),
#  ('completes', 'VBZ'),
#  ('the', 'DT'),
#  ('lengthy', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('process', 'NN'),
#  ('in', 'IN'),
#  ('2020', 'CD'),
#  ('.', '.'),
#  ("'It", 'PRP'),
#  ("'s", 'VBZ'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('word', 'NN'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('use', 'VB'),
#  ("'", 'POS'),
#  ('Macron', 'NNP'),
#  ('also', 'RB'),
#  ('criticized', 'VBD'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('alleged', 'VBN'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  ('``', '``'),
#  ('shitholes', 'NNS'),
#  ("''", "''"),
#  ('to', 'TO'),
#  ('describe', 'VB'),
#  ('certain', 'JJ'),
#  ('countries', 'NNS'),
#  ('while', 'IN'),
#  ('discussing', 'VBG'),
#  ('immigration', 'NN'),
#  ('with', 'IN'),
#  ('lawmakers', 'NNS'),
#  ('earlier', 'RBR'),
#  ('this', 'DT'),
#  ('month', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('year', 'NN'),
#  ('of', 'IN'),
#  ('Trump', 'NN'),
#  (':', ':'),
#  ('(', '('),
#  ('Almost', 'NNP'),
#  (')', ')'),
#  ('everything', 'NN'),
#  ('that', 'WDT'),
#  ('happened', 'VBD'),
#  ("''", "''"),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('word', 'NN'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('use', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Macron', 'NNP'),
#  ('about', 'IN'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('reported', 'JJ'),
#  ('comment', 'NN'),
#  (',', ','),
#  ('adding', 'VBG'),
#  ('``', '``'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('respect', 'VB'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('countries', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('issues', 'NNS'),
#  ('in', 'IN'),
#  ('both', 'DT'),
#  ('the', 'DT'),
#  ('Middle', 'NNP'),
#  ('East', 'NNP'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('Africa', 'NNP'),
#  ('is', 'VBZ'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('frustrations', 'NNS'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('past', 'JJ'),
#  ('humiliations', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('Macron', 'NNP'),
#  ('said.When', 'NN'),
#  ('asked', 'VBD'),
#  ('about', 'IN'),
#  ('his', 'PRP$'),
#  ('opinion', 'NN'),
#  ('on', 'IN'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('tweets', 'NNS'),
#  (',', ','),
#  ('Macron', 'NNP'),
#  ('replied', 'VBD'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('should', 'MD'),
#  ("n't", 'RB'),
#  ('``', '``'),
#  ('overplay', 'VB'),
#  ('the', 'DT'),
#  ('situation', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('saying', 'VBG'),
#  ('the', 'DT'),
#  ('tweets', 'NNS'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('mix', 'NN'),
#  ('between', 'IN'),
#  ('personal', 'JJ'),
#  ('and', 'CC'),
#  ('political', 'JJ'),
#  ('reaction', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Macron', 'NNP'),
#  (':', ':'),
#  ('Trump', 'NN'),
#  ("'s", 'POS'),
#  ('interpreter', 'NN'),
#  ('in', 'IN'),
#  ('Europe', 'NNP'),
#  ('?', '.'),
#  ('Macron', 'NNP'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('small', 'JJ'),
#  ('club', 'NN'),
#  ('of', 'IN'),
#  ('leaders', 'NNS'),
#  ('with', 'IN'),
#  ('less', 'JJR'),
#  ('experience', 'NN'),
#  ('in', 'IN'),
#  ('office', 'NN'),
#  ('than', 'IN'),
#  ('Trump', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('40-year-old', 'JJ'),
#  ('French', 'JJ'),
#  ('President', 'NNP'),
#  ('appears', 'VBZ'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('used', 'VBN'),
#  ('that', 'IN'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('advantage', 'NN'),
#  (',', ','),
#  ('forging', 'VBG'),
#  ('strong', 'JJ'),
#  ('ties', 'NNS'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('mutual', 'JJ'),
#  ('desire', 'NN'),
#  ('to', 'TO'),
#  ('change', 'VB'),
#  ('the', 'DT'),
#  ('status', 'NN'),
#  ('quo.Read', 'VBD'),
#  ('more', 'RBR'),
#  (':', ':'),
#  ('Trump', 'NN'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('year', 'NN'),
#  ('--', ':'),
#  ('diplomacy', 'NN'),
#  ('finds', 'VBZ'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('foes', 'NNS'),
#  ('Trump', 'NNP'),
#  ('has', 'VBZ'),
#  ('replaced', 'VBN'),
#  ('old', 'JJ'),
#  ('international', 'JJ'),
#  ('allies', 'NNS'),
#  ('with', 'IN'),
#  ('new', 'JJ'),
#  ('onesSince', 'NN'),
#  ('their', 'PRP$'),
#  ('first', 'JJ'),
#  ('eye-catching', 'JJ'),
#  ('handshake', 'NN'),
#  ('in', 'IN'),
#  ('Brussels', 'NNP'),
#  (',', ','),
#  ('there', 'EX'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('highs', 'NNS'),
#  ('(', '('),
#  ('an', 'DT'),
#  ('intimate', 'NN'),
#  ('dinner', 'NN'),
#  ('with', 'IN'),
#  ('wives', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('landing', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('lows', 'NNS'),
#  ('(', '('),
#  ('Macron', 'NNP'),
#  ('has', 'VBZ'),
#  ('openly', 'RB'),
#  ('aired', 'VBN'),
#  ('his', 'PRP$'),
#  ('disagreements', 'NNS'),
#  ('with', 'IN'),
#  ('Trump', 'NNP'),
#  ('on', 'IN'),
#  ('Iran', 'NNP'),
#  (',', ','),
#  ('climate', 'NN'),
#  ('change', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Middle', 'NNP'),
#  ('East', 'NNP'),
#  ('.', '.'),
#  (')', ')'),
#  ('Through', 'IN'),
#  ('it', 'PRP'),
#  ('all', 'DT'),
#  (',', ','),
#  ('Macron', 'NNP'),
#  ("'s", 'POS'),
#  ('aides', 'NNS'),
#  ('say', 'VBP'),
#  ('he', 'PRP'),
#  ('views', 'VBZ'),
#  ('himself', 'PRP'),
#  ('as', 'IN'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('interpreter', 'NN'),
#  ('in', 'IN'),
#  ('Europe', 'NNP'),
#  (',', ','),
#  ('sifting', 'VBG'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('brash', 'NN'),
#  ('pronouncements', 'NNS'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('places', 'NNS'),
#  ('of', 'IN'),
#  ('common', 'JJ'),
#  ('interest', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('as', 'IN'),
#  ('leaders', 'NNS'),
#  ('in', 'IN'),
#  ('Berlin', 'NNP'),
#  ('and', 'CC'),
#  ('London', 'NNP'),
#  ('find', 'VBP'),
#  ('themselves', 'PRP'),
#  ('distracted', 'VBN'),
#  ('by', 'IN'),
#  ('internal', 'JJ'),
#  ('politics', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('coalition', 'NN'),
#  ('negotiations', 'NNS'),
#  ('and', 'CC'),
#  ('Brexit', 'NNP'),
#  (',', ','),
#  ('Paris-Washington', 'NNP'),
#  ('ties', 'NNS'),
#  ('are', 'VBP'),
#  ('enjoying', 'VBG'),
#  ('renewed', 'VBN'),
#  ('strength', 'NN'),
#  ('.', '.'),
#  ('CNN', 'NNP'),
#  ("'s", 'POS'),
#  ('Kevin', 'NNP'),
#  ('Liptak', 'NNP'),
#  ('and', 'CC'),
#  ('Dan', 'NNP'),
#  ('Merica', 'NNP'),
#  ('contributed', 'VBD'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('report', 'NN'),
#  ('45CongressSecurityThe', 'CD'),
#  ('NineTrumpmericaState©', 'NNP'),
#  ('2018', 'CD'),
#  ('Cable', 'NNP'),
#  ('News', 'NNP'),
#  ('Network', 'NNP'),
#  ('.', '.'),
#  ('Turner', 'NNP'),
#  ('Broadcasting', 'NNP'),
#  ('System', 'NNP'),
#  (',', ','),
#  ('Inc.', 'NNP'),
#  ('All', 'NNP'),
#  ('Rights', 'NNP'),
#  ('Reserved', 'NNP'),
#  ('.', '.'),
#  ('CNN', 'NNP'),
#  ('Sans', 'NNPS'),
#  ('™', 'NNP'),
#  ('&', 'CC'),
#  ('©', 'NNP'),
#  ('2016', 'CD'),
#  ('Cable', 'NNP'),
#  ('News', 'NNP'),
#  ('Network.Terms', 'NNP'),
#  ('of', 'IN'),
#  ('service', 'NN'),
#  ('|', 'NNP'),
#  ('Privacy', 'NNP'),
#  ('guidelines', 'NNS'),
#  ('|', 'NNP'),
#  ('AdChoices', 'NNS')]

# %% [markdown]
# # Calculate the sentiment

# %%
analyser = SentimentIntensityAnalyzer()
def print_sentiment_scores(sentence):
    snt = analyser.polarity_scores(sentence)
    print(snt)
    
print_sentiment_scores(text)
# Out:
# {'neg': 0.05, 'neu': 0.849, 'pos': 0.101, 'compound': 0.9901}

# %%
data = text
stopWords = set(stopwords.words('english'))
words = word_tokenize(data)
wordsFiltered = []

for w in words:
    if w not in stopWords:
        wordsFiltered.append(w)
print(wordsFiltered)
print(len(stopWords))
print(stopWords)
# Out:
# ['Macron', ':', "'I", 'direct', 'relationship', 'Trump', "'", '-', 'CNNPoliticsBreaking', 'News45CongressSecurityThe', 'NineTrumpmericaStateSearch', '»', 'French', 'President', 'Macron', "'a", 'direct', 'relationship', 'Trump', "'", 'By', 'Sheena', 'McKenzie', ',', 'Carol', 'Jordan', 'Amanda', 'Coakley', ',', 'CNNUpdated', '0749', 'GMT', '(', '1549', 'HKT', ')', 'January', '22', ',', '2018', 'Chat', 'us', 'Facebook', 'Messenger', '.', 'Find', "'s", 'happening', 'world', 'unfolds.JUST', 'WATCHEDWhat', 'know', 'Emmanuel', 'MacronReplayMore', 'Videos', '...', 'MUST', 'WATCHWhat', 'know', 'Emmanuel', 'Macron', '01:32', '(', 'CNN', ')', 'Their', 'first', 'meeting', 'Brussels', 'symbolized', 'prolonged', ',', 'white-knuckle', 'handshake', '--', 'months', 'later', 'appears', 'French', 'President', 'Emmanuel', 'Macron', 'US', 'President', 'Donald', 'Trump', 'continue', 'forceful', 'exchanges.Macron', 'shed', 'light', 'Sunday', '``', 'direct', 'relationship', "''", 'Trump', ',', 'telling', 'BBC', "'s", '``', 'The', 'Andrew', 'Marr', 'Show', "''", 'two', 'leaders', 'talk', '``', 'regularly', '.', '``', '``', 'I', "'m", 'always', 'extremely', 'direct', 'frank', '.', 'He', '.', 'Sometimes', 'I', 'manage', 'convince', ',', 'sometimes', 'I', 'fail', ',', "''", 'Macron', 'said', 'British', 'talk', 'show.Macron', 'added', 'Trump', '``', 'classical', 'politician', "''", '``', 'elected', 'humoring', 'people', '.', '``', 'Paris', 'agreement', ':', "'no", "renegotiation'Read", 'MoreMacron', ',', 'elected', 'May', 'last', 'year', ',', 'said', 'two', 'leaders', '``', 'built', 'strong', 'relationship', '.', "''", 'However', 'also', 'disagreed', 'several', 'topics', ',', 'including', 'Paris', 'agreement', 'climate', 'change', ',', 'Trump', 'plans', 'withdraw', 'unless', 'terms', 'renegotiated.Macron', 'said', 'US', 'could', 'choose', 'signing', 'signing', 'treaty', ',', 'adding', '``', 'renegotiate', 'one', 'people', '.', '``', 'JUST', 'WATCHEDPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunityReplayMore', 'Videos', '...', 'MUST', 'WATCHPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunity', '02:22', "''", 'I', 'believe', "'s", 'big', 'mistake', ',', 'I', 'told', 'new', 'negotiation', '.', 'You', 'join', "n't", 'join', '.', 'China', 'decided', ',', 'remain', 'loop', ',', "''", 'Macron', 'said.The', 'Paris', 'agreement', 'pushes', 'signatories', 'reduce', 'carbon', 'output', 'hold', 'global', 'warming', 'two', 'degrees', 'Celsius', 'end', 'century.While', 'former', 'President', 'Barack', 'Obama', 'described', '``', 'best', 'chance', 'save', 'one', 'planet', "'ve", 'got', ',', "''", 'Trump', 'far', 'complimentary.As', 'things', 'stand', ',', 'US', 'country', 'world', 'signed', 'accord', 'completes', 'lengthy', 'withdrawal', 'process', '2020', '.', "'It", "'s", 'word', 'use', "'", 'Macron', 'also', 'criticized', 'Trump', "'s", 'alleged', 'use', 'word', '``', 'shitholes', "''", 'describe', 'certain', 'countries', 'discussing', 'immigration', 'lawmakers', 'earlier', 'month', '.', 'A', 'year', 'Trump', ':', '(', 'Almost', ')', 'everything', 'happened', "''", 'It', "'s", 'word', 'use', ',', "''", 'said', 'Macron', 'Trump', "'s", 'reported', 'comment', ',', 'adding', '``', 'respect', 'countries', '.', '``', '``', 'I', 'think', 'lot', 'issues', 'Middle', 'East', 'Africa', 'due', 'lot', 'frustrations', 'due', 'lot', 'past', 'humiliations', ',', "''", 'Macron', 'said.When', 'asked', 'opinion', 'Trump', "'s", 'tweets', ',', 'Macron', 'replied', 'people', "n't", '``', 'overplay', 'situation', ',', "''", 'saying', 'tweets', '``', 'mix', 'personal', 'political', 'reaction', '.', '``', 'Macron', ':', 'Trump', "'s", 'interpreter', 'Europe', '?', 'Macron', 'one', 'small', 'club', 'leaders', 'less', 'experience', 'office', 'Trump', '.', 'The', '40-year-old', 'French', 'President', 'appears', 'used', 'advantage', ',', 'forging', 'strong', 'ties', 'White', 'House', 'based', 'mutual', 'desire', 'change', 'status', 'quo.Read', ':', 'Trump' ...
# 179
# {'didn', 'from', 'themselves', 'mustn', 'being', 'do', 'who', 'before', "wasn't", 'down', 'most', 'are', "you've", 'couldn', 'had', 'does', 'during', 'doesn', 'weren', 'yours', 'him', 'needn', 'won', 'am', 'myself', "should've", 'o', 'their', 'll', 'no', 'same', 'all', "haven't", 'his', 'don', "couldn't", 'own', 'further', 'just', 'above', 'herself', 'then', 'its', 'up', "mustn't", "you'd", 'mightn', 'ours', 'those', "doesn't", 'hasn', 'ourselves', "aren't", "won't", 'because', 'having', 'on', 'which', 'both', 'through', 'where', 'other', 'than', "needn't", "shouldn't", "she's", 'against', 'himself', 'how', 'm', 'until', 'my', 'isn', 'wouldn', 'you', 'not', 'aren', 'while', 'by', 'doing', "wouldn't", 've', 'a', 'me', 'her', 'been', 'your', 'yourselves', 'or', 'once', 'have', 'when', "shan't", 'here', 're', 'for', 'if', 'some', 'below', 'we', "hadn't", 'be', 'should', 'only', 'whom', 'each', 'they', 'hadn', 's', 'and', 'in', 'about', 'did', 'more', 'it', 'ain', 'has', 'too', 'them', 'shouldn', 'that', 'haven', 'very', "it's", 'itself', "isn't", 'hers', 'nor', 'were', "you're", 'now', 'as', "weren't", 'wasn', 'ma', 'will', 'of', "hasn't", 'such', 'yourself', "that'll", 'theirs', 'he', 'y', 'there', 'so', 'd', 't', 'what', 'i', 'over', 'off', 'out', 'under', 'to', 'this', 'between', "didn't", 'why', 'these', 'shan', 'at', 'she', 'few', 'was', 'an', "don't", 'into', "mightn't", 'again', 'is', 'but', 'our', "you'll", 'after', 'can', 'with', 'the', 'any'}

# %%
ps = PorterStemmer()
example_words = ["kill","killer","killing","killed"]
for w in example_words:
    print(ps.stem(w))
# Out:
# kill
# killer
# kill
# kill

# %%
test_subset = ['Macron', ':', "'I", 'direct', 'relationship', 'Trump', "'", '-', 'CNNPoliticsBreaking', 'News45CongressSecurityThe', 'NineTrumpmericaStateSearch', '»', 'French', 'President', 'Macron', "'a", 'direct', 'relationship', 'Trump', "'", 'By', 'Sheena', 'McKenzie', ',', 'Carol', 'Jordan', 'Amanda', 'Coakley', ',', 'CNNUpdated', '0749', 'GMT', '(', '1549', 'HKT', ')', 'January', '22', ',', '2018', 'Chat', 'us', 'Facebook', 'Messenger', '.', 'Find', "'s", 'happening', 'world', 'unfolds.JUST', 'WATCHEDWhat', 'know', 'Emmanuel', 'MacronReplayMore', 'Videos', '...', 'MUST', 'WATCHWhat', 'know', 'Emmanuel', 'Macron', '01:32', '(', 'CNN', ')', 'Their', 'first', 'meeting', 'Brussels', 'symbolized', 'prolonged', ',', 'white-knuckle', 'handshake', '--', 'months', 'later', 'appears', 'French', 'President', 'Emmanuel', 'Macron', 'US', 'President', 'Donald', 'Trump', 'continue', 'forceful', 'exchanges.Macron', 'shed', 'light', 'Sunday', '``', 'direct', 'relationship', "''", 'Trump', ',', 'telling', 'BBC', "'s", '``', 'The', 'Andrew', 'Marr', 'Show', "''", 'two', 'leaders', 'talk', '``', 'regularly', '.', '``', '``', 'I', "'m", 'always', 'extremely', 'direct', 'frank', '.', 'He', '.', 'Sometimes', 'I', 'manage', 'convince', ',', 'sometimes', 'I', 'fail', ',', "''", 'Macron', 'said', 'British', 'talk', 'show.Macron', 'added', 'Trump', '``', 'classical', 'politician', "''", '``', 'elected', 'humoring', 'people', '.', '``', 'Paris', 'agreement', ':', "'no", "renegotiation'Read", 'MoreMacron', ',', 'elected', 'May', 'last', 'year', ',', 'said', 'two', 'leaders', '``', 'built', 'strong', 'relationship', '.', "''", 'However', 'also', 'disagreed', 'several', 'topics', ',', 'including', 'Paris', 'agreement', 'climate', 'change', ',', 'Trump', 'plans', 'withdraw', 'unless', 'terms', 'renegotiated.Macron', 'said', 'US', 'could', 'choose', 'signing', 'signing', 'treaty', ',', 'adding', '``', 'renegotiate', 'one', 'people', '.', '``', 'JUST', 'WATCHEDPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunityReplayMore', 'Videos', '...', 'MUST', 'WATCHPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunity', '02:22', "''", 'I', 'believe', "'s", 'big', 'mistake', ',', 'I', 'told', 'new', 'negotiation', '.', 'You', 'join', "n't", 'join', '.', 'China', 'decided', ',', 'remain', 'loop', ',', "''", 'Macron', 'said.The', 'Paris', 'agreement', 'pushes', 'signatories', 'reduce', 'carbon', 'output', 'hold', 'global', 'warming', 'two', 'degrees', 'Celsius', 'end', 'century.While', 'former', 'President', 'Barack', 'Obama', 'described', '``', 'best', 'chance', 'save', 'one', 'planet', "'ve", 'got', ',', "''", 'Trump', 'far', 'complimentary.As', 'things', 'stand', ',', 'US', 'country', 'world', 'signed', 'accord', 'completes', 'lengthy', 'withdrawal', 'process', '2020', '.', "'It", "'s", 'word', 'use', "'", 'Macron', 'also', 'criticized', 'Trump', "'s", 'alleged', 'use', 'word', '``', 'shitholes', "''", 'describe', 'certain', 'countries', 'discussing', 'immigration', 'lawmakers', 'earlier', 'month', '.', 'A', 'year', 'Trump', ':', '(', 'Almost', ')', 'everything', 'happened', "''", 'It', "'s", 'word', 'use', ',', "''", 'said', 'Macron', 'Trump', "'s", 'reported', 'comment', ',', 'adding', '``', 'respect', 'countries', '.', '``', '``', 'I', 'think', 'lot', 'issues', 'Middle', 'East', 'Africa', 'due', 'lot', 'frustrations', 'due', 'lot', 'past', 'humiliations', ',', "''", 'Macron', 'said.When', 'asked', 'opinion', 'Trump', "'s", 'tweets', ',', 'Macron', 'replied', 'people', "n't", '``', 'overplay', 'situation', ',', "''", 'saying', 'tweets', '``', 'mix', 'personal', 'political', 'reaction', '.', '``', 'Macron', ':', 'Trump', "'s", 'interpreter', 'Europe', '?', 'Macron', 'one', 'small', 'club', 'leaders', 'less', 'experience', 'office', 'Trump', '.', 'The', '40-year-old', 'French', 'President', 'appears', 'used', 'advantage', ',', 'forging', 'strong', 'ties', 'White', 'House', 'based', 'mutual', 'desire', 'change', 'status', 'quo.Read', ':', 'Trump', "'s", 'first', 'year', '--', 'diplomacy', 'finds', 'friends', 'foes', 'Trump', 'replaced', 'old', 'international', 'allies', 'new', 'onesSince', 'first', 'eye-catching', 'handshake', 'Brussels', ',', 'highs', '(', 'intimate', 'dinner', 'wives', 'second', 'landing', 'Eiffel', 'Tower', ')', 'lows', '(', 'Macron', 'openly', 'aired', 'disagreements', 'Trump', 'Iran', ',', 'climate', 'change', 'Middle', 'East', '.', ')', 'Through', ',', 'Macron', "'s", 'aides', 'say', 'views', 'Trump', "'s", 'interpreter', 'Europe', ',', 'sifting', 'brash', 'pronouncements', 'find', 'places', 'common', 'interest', '.', 'And', 'leaders', 'Berlin', 'London', 'find', 'distracted', 'internal', 'politics', ',', 'including', 'coalition', 'negotiations', 'Brexit', ',', 'Paris-Washington', 'ties', 'enjoying', 'renewed', 'strength', '.', 'CNN', "'s", 'Kevin', 'Liptak', 'Dan', 'Merica', 'contributed', 'report', '45CongressSecurityThe', 'NineTrumpmericaState©', '2018', 'Cable', 'News', 'Network', '.', 'Turner', 'Broadcasting', 'System', ',', 'Inc.', 'All', 'Rights', 'Reserved', '.', 'CNN', 'Sans', '™', '&', '©', '2016', 'Cable', 'News', 'Network.Terms', 'service', '|', 'Privacy', 'guidelines', '|', 'AdChoices']
179
{'didn', 'from', 'themselves', 'mustn', 'being', 'do', 'who', 'before', "wasn't", 'down', 'most', 'are', "you've", 'couldn', 'had', 'does', 'during', 'doesn', 'weren', 'yours', 'him', 'needn', 'won', 'am', 'myself', "should've", 'o', 'their', 'll', 'no', 'same', 'all', "haven't", 'his', 'don', "couldn't", 'own', 'further', 'just', 'above', 'herself', 'then', 'its', 'up', "mustn't", "you'd", 'mightn', 'ours', 'those', "doesn't", 'hasn', 'ourselves', "aren't", "won't", 'because', 'having', 'on', 'which', 'both', 'through', 'where', 'other', 'than', "needn't", "shouldn't", "she's", 'against', 'himself', 'how', 'm', 'until', 'my', 'isn', 'wouldn', 'you', 'not', 'aren', 'while', 'by', 'doing', "wouldn't", 've', 'a', 'me', 'her', 'been', 'your', 'yourselves', 'or', 'once', 'have', 'when', "shan't", 'here', 're', 'for', 'if', 'some', 'below', 'we', "hadn't", 'be', 'should', 'only', 'whom', 'each', 'they', 'hadn', 's', 'and', 'in', 'about', 'did', 'more', 'it', 'ain', 'has', 'too', 'them', 'shouldn', 'that', 'haven', 'very', "it's", 'itself', "isn't", 'hers', 'nor', 'were', "you're", 'now', 'as', "weren't", 'wasn', 'ma', 'will', 'of', "hasn't", 'such', 'yourself', "that'll", 'theirs', 'he', 'y', 'there', 'so', 'd', 't', 'what', 'i', 'over', 'off', 'out', 'under', 'to', 'this', 'between', "didn't", 'why', 'these', 'shan', 'at', 'she', 'few', 'was', 'an', "don't", 'into', "mightn't", 'again', 'is', 'but', 'our', "you'll", 'after', 'can', 'with', 'the', 'any'}

sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neu_word_list=[]
neg_word_list=[]

for word in test_subset:
    if (sid.polarity_scores(word)['compound']) >= 0.5:
        pos_word_list.append(word)
    elif (sid.polarity_scores(word)['compound']) <= -0.5:
        neg_word_list.append(word)
    else:
        neu_word_list.append(word)                

print('Positive :',pos_word_list)        
print('Neutral :',neu_word_list)    
print('Negative :',neg_word_list)
# Out:
# Positive : ['strong', 'best', 'strong', 'enjoying']
# Neutral : ['Macron', ':', "'I", 'direct', 'relationship', 'Trump', "'", '-', 'CNNPoliticsBreaking', 'News45CongressSecurityThe', 'NineTrumpmericaStateSearch', '»', 'French', 'President', 'Macron', "'a", 'direct', 'relationship', 'Trump', "'", 'By', 'Sheena', 'McKenzie', ',', 'Carol', 'Jordan', 'Amanda', 'Coakley', ',', 'CNNUpdated', '0749', 'GMT', '(', '1549', 'HKT', ')', 'January', '22', ',', '2018', 'Chat', 'us', 'Facebook', 'Messenger', '.', 'Find', "'s", 'happening', 'world', 'unfolds.JUST', 'WATCHEDWhat', 'know', 'Emmanuel', 'MacronReplayMore', 'Videos', '...', 'MUST', 'WATCHWhat', 'know', 'Emmanuel', 'Macron', '01:32', '(', 'CNN', ')', 'Their', 'first', 'meeting', 'Brussels', 'symbolized', 'prolonged', ',', 'white-knuckle', 'handshake', '--', 'months', 'later', 'appears', 'French', 'President', 'Emmanuel', 'Macron', 'US', 'President', 'Donald', 'Trump', 'continue', 'forceful', 'exchanges.Macron', 'shed', 'light', 'Sunday', '``', 'direct', 'relationship', "''", 'Trump', ',', 'telling', 'BBC', "'s", '``', 'The', 'Andrew', 'Marr', 'Show', "''", 'two', 'leaders', 'talk', '``', 'regularly', '.', '``', '``', 'I', "'m", 'always', 'extremely', 'direct', 'frank', '.', 'He', '.', 'Sometimes', 'I', 'manage', 'convince', ',', 'sometimes', 'I', ',', "''", 'Macron', 'said', 'British', 'talk', 'show.Macron', 'added', 'Trump', '``', 'classical', 'politician', "''", '``', 'elected', 'humoring', 'people', '.', '``', 'Paris', 'agreement', ':', "'no", "renegotiation'Read", 'MoreMacron', ',', 'elected', 'May', 'last', 'year', ',', 'said', 'two', 'leaders', '``', 'built', 'relationship', '.', "''", 'However', 'also', 'disagreed', 'several', 'topics', ',', 'including', 'Paris', 'agreement', 'climate', 'change', ',', 'Trump', 'plans', 'withdraw', 'unless', 'terms', 'renegotiated.Macron', 'said', 'US', 'could', 'choose', 'signing', 'signing', 'treaty', ',', 'adding', '``', 'renegotiate', 'one', 'people', '.', '``', 'JUST', 'WATCHEDPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunityReplayMore', 'Videos', '...', 'MUST', 'WATCHPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunity', '02:22', "''", 'I', 'believe', "'s", 'big', 'mistake', ',', 'I', 'told', 'new', 'negotiation', '.', 'You', 'join', "n't", 'join', '.', 'China', 'decided', ',', 'remain', 'loop', ',', "''", 'Macron', 'said.The', 'Paris', 'agreement', 'pushes', 'signatories', 'reduce', 'carbon', 'output', 'hold', 'global', 'warming', 'two', 'degrees', 'Celsius', 'end', 'century.While', 'former', 'President', 'Barack', 'Obama', 'described', '``', 'chance', 'save', 'one', 'planet', "'ve", 'got', ',', "''", 'Trump', 'far', 'complimentary.As', 'things', 'stand', ',', 'US', 'country', 'world', 'signed', 'accord', 'completes', 'lengthy', 'withdrawal', 'process', '2020', '.', "'It", "'s", 'word', 'use', "'", 'Macron', 'also', 'criticized', 'Trump', "'s", 'alleged', 'use', 'word', '``', 'shitholes', "''", 'describe', 'certain', 'countries', 'discussing', 'immigration', 'lawmakers', 'earlier', 'month', '.', 'A', 'year', 'Trump', ':', '(', 'Almost', ')', 'everything', 'happened', "''", 'It', "'s", 'word', 'use', ',', "''", 'said', 'Macron', 'Trump', "'s", 'reported', 'comment', ',', 'adding', '``', 'respect', 'countries', '.', '``', '``', 'I', 'think', 'lot', 'issues', 'Middle', 'East', 'Africa', 'due', 'lot', 'frustrations', 'due', 'lot', 'past', ',', "''", 'Macron', 'said.When', 'asked', 'opinion', 'Trump', "'s", 'tweets', ',', 'Macron', 'replied', 'people', "n't", '``', 'overplay', 'situation', ',', "''", 'saying', 'tweets', '``', 'mix', 'personal', 'political', 'reaction', '.', '``', 'Macron', ':', 'Trump', "'s", 'interpreter', 'Europe', '?', 'Macron', 'one', 'small', 'club', 'leaders', 'less', 'experience', 'office', 'Trump', '.', 'The', '40-year-old', 'French', 'President', 'appears', 'used', 'advantage', ',', 'forging', 'ties', 'White', 'House', 'based', 'mutual', 'desire', 'change', 'status', 'quo.Read', ':', 'Trump', "'s", 'first', 'year', '--', 'diplomacy' ...
# Negative : ['fail', 'humiliations']

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
test_subset=['Macron', ':', "'I", 'direct', 'relationship', 'Trump', "'", '-', 'CNNPoliticsBreaking', 'News45CongressSecurityThe', 'NineTrumpmericaStateSearch', '»', 'French', 'President', 'Macron', "'a", 'direct', 'relationship', 'Trump', "'", 'By', 'Sheena', 'McKenzie', ',', 'Carol', 'Jordan', 'Amanda', 'Coakley', ',', 'CNNUpdated', '0749', 'GMT', '(', '1549', 'HKT', ')', 'January', '22', ',', '2018', 'Chat', 'us', 'Facebook', 'Messenger', '.', 'Find', "'s", 'happening', 'world', 'unfolds.JUST', 'WATCHEDWhat', 'know', 'Emmanuel', 'MacronReplayMore', 'Videos', '...', 'MUST', 'WATCHWhat', 'know', 'Emmanuel', 'Macron', '01:32', '(', 'CNN', ')', 'Their', 'first', 'meeting', 'Brussels', 'symbolized', 'prolonged', ',', 'white-knuckle', 'handshake', '--', 'months', 'later', 'appears', 'French', 'President', 'Emmanuel', 'Macron', 'US', 'President', 'Donald', 'Trump', 'continue', 'forceful', 'exchanges.Macron', 'shed', 'light', 'Sunday', '``', 'direct', 'relationship', "''", 'Trump', ',', 'telling', 'BBC', "'s", '``', 'The', 'Andrew', 'Marr', 'Show', "''", 'two', 'leaders', 'talk', '``', 'regularly', '.', '``', '``', 'I', "'m", 'always', 'extremely', 'direct', 'frank', '.', 'He', '.', 'Sometimes', 'I', 'manage', 'convince', ',', 'sometimes', 'I', 'fail', ',', "''", 'Macron', 'said', 'British', 'talk', 'show.Macron', 'added', 'Trump', '``', 'classical', 'politician', "''", '``', 'elected', 'humoring', 'people', '.', '``', 'Paris', 'agreement', ':', "'no", "renegotiation'Read", 'MoreMacron', ',', 'elected', 'May', 'last', 'year', ',', 'said', 'two', 'leaders', '``', 'built', 'strong', 'relationship', '.', "''", 'However', 'also', 'disagreed', 'several', 'topics', ',', 'including', 'Paris', 'agreement', 'climate', 'change', ',', 'Trump', 'plans', 'withdraw', 'unless', 'terms', 'renegotiated.Macron', 'said', 'US', 'could', 'choose', 'signing', 'signing', 'treaty', ',', 'adding', '``', 'renegotiate', 'one', 'people', '.', '``', 'JUST', 'WATCHEDPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunityReplayMore', 'Videos', '...', 'MUST', 'WATCHPM', 'warns', 'Trump', ':', 'Do', "n't", 'miss', 'good', 'opportunity', '02:22', "''", 'I', 'believe', "'s", 'big', 'mistake', ',', 'I', 'told', 'new', 'negotiation', '.', 'You', 'join', "n't", 'join', '.', 'China', 'decided', ',', 'remain', 'loop', ',', "''", 'Macron', 'said.The', 'Paris', 'agreement', 'pushes', 'signatories', 'reduce', 'carbon', 'output', 'hold', 'global', 'warming', 'two', 'degrees', 'Celsius', 'end', 'century.While', 'former', 'President', 'Barack', 'Obama', 'described', '``', 'best', 'chance', 'save', 'one', 'planet', "'ve", 'got', ',', "''", 'Trump', 'far', 'complimentary.As', 'things', 'stand', ',', 'US', 'country', 'world', 'signed', 'accord', 'completes', 'lengthy', 'withdrawal', 'process', '2020', '.', "'It", "'s", 'word', 'use', "'", 'Macron', 'also', 'criticized', 'Trump', "'s", 'alleged', 'use', 'word', '``', 'shitholes', "''", 'describe', 'certain', 'countries', 'discussing', 'immigration', 'lawmakers', 'earlier', 'month', '.', 'A', 'year', 'Trump', ':', '(', 'Almost', ')', 'everything', 'happened', "''", 'It', "'s", 'word', 'use', ',', "''", 'said', 'Macron', 'Trump', "'s", 'reported', 'comment', ',', 'adding', '``', 'respect', 'countries', '.', '``', '``', 'I', 'think', 'lot', 'issues', 'Middle', 'East', 'Africa', 'due', 'lot', 'frustrations', 'due', 'lot', 'past', 'humiliations', ',', "''", 'Macron', 'said.When', 'asked', 'opinion', 'Trump', "'s", 'tweets', ',', 'Macron', 'replied', 'people', "n't", '``', 'overplay', 'situation', ',', "''", 'saying', 'tweets', '``', 'mix', 'personal', 'political', 'reaction', '.', '``', 'Macron', ':', 'Trump', "'s", 'interpreter', 'Europe', '?', 'Macron', 'one', 'small', 'club', 'leaders', 'less', 'experience', 'office', 'Trump', '.', 'The', '40-year-old', 'French', 'President', 'appears', 'used', 'advantage', ',', 'forging', 'strong', 'ties', 'White', 'House', 'based', 'mutual', 'desire', 'change', 'status', 'quo.Read', ':', 'Trump', "'s", 'first', 'year', '--', 'diplomacy', 'finds', 'friends', 'foes', 'Trump', 'replaced', 'old', 'international', 'allies', 'new', 'onesSince', 'first', 'eye-catching', 'handshake', 'Brussels', ',', 'highs', '(', 'intimate', 'dinner', 'wives', 'second', 'landing', 'Eiffel', 'Tower', ')', 'lows', '(', 'Macron', 'openly', 'aired', 'disagreements', 'Trump', 'Iran', ',', 'climate', 'change', 'Middle', 'East', '.', ')', 'Through', ',', 'Macron', "'s", 'aides', 'say', 'views', 'Trump', "'s", 'interpreter', 'Europe', ',', 'sifting', 'brash', 'pronouncements', 'find', 'places', 'common', 'interest', '.', 'And', 'leaders', 'Berlin', 'London', 'find', 'distracted', 'internal', 'politics', ',', 'including', 'coalition', 'negotiations', 'Brexit', ',', 'Paris-Washington', 'ties', 'enjoying', 'renewed', 'strength', '.', 'CNN', "'s", 'Kevin', 'Liptak', 'Dan', 'Merica', 'contributed', 'report', '45CongressSecurityThe', 'NineTrumpmericaState©', '2018', 'Cable', 'News', 'Network', '.', 'Turner', 'Broadcasting', 'System', ',', 'Inc.', 'All', 'Rights', 'Reserved', '.', 'CNN', 'Sans', '™', '&', '©', '2016', 'Cable', 'News', 'Network.Terms', 'service', '|', 'Privacy', 'guidelines', '|', 'AdChoices']
179
{'didn', 'from', 'themselves', 'mustn', 'being', 'do', 'who', 'before', "wasn't", 'down', 'most', 'are', "you've", 'couldn', 'had', 'does', 'during', 'doesn', 'weren', 'yours', 'him', 'needn', 'won', 'am', 'myself', "should've", 'o', 'their', 'll', 'no', 'same', 'all', "haven't", 'his', 'don', "couldn't", 'own', 'further', 'just', 'above', 'herself', 'then', 'its', 'up', "mustn't", "you'd", 'mightn', 'ours', 'those', "doesn't", 'hasn', 'ourselves', "aren't", "won't", 'because', 'having', 'on', 'which', 'both', 'through', 'where', 'other', 'than', "needn't", "shouldn't", "she's", 'against', 'himself', 'how', 'm', 'until', 'my', 'isn', 'wouldn', 'you', 'not', 'aren', 'while', 'by', 'doing', "wouldn't", 've', 'a', 'me', 'her', 'been', 'your', 'yourselves', 'or', 'once', 'have', 'when', "shan't", 'here', 're', 'for', 'if', 'some', 'below', 'we', "hadn't", 'be', 'should', 'only', 'whom', 'each', 'they', 'hadn', 's', 'and', 'in', 'about', 'did', 'more', 'it', 'ain', 'has', 'too', 'them', 'shouldn', 'that', 'haven', 'very', "it's", 'itself', "isn't", 'hers', 'nor', 'were', "you're", 'now', 'as', "weren't", 'wasn', 'ma', 'will', 'of', "hasn't", 'such', 'yourself', "that'll", 'theirs', 'he', 'y', 'there', 'so', 'd', 't', 'what', 'i', 'over', 'off', 'out', 'under', 'to', 'this', 'between', "didn't", 'why', 'these', 'shan', 'at', 'she', 'few', 'was', 'an', "don't", 'into', "mightn't", 'again', 'is', 'but', 'our', "you'll", 'after', 'can', 'with', 'the', 'any'} 

sid = SentimentIntensityAnalyzer()

neg_word_list=[]

for word in test_subset:

    if (sid.polarity_scores(word)['compound']) <= -0.4:
        neg_word_list.append(word)
                     
print('Negative :',neg_word_list)
# Out:
# Negative : ['fail', 'frustrations', 'humiliations', 'foes', 'disagreements']
